# %%
import math as m
import numpy as np
import csv
mo_phong=[]
for i in range(0,180,1):
  arr=[]  
  for j in range(0,180,1):
      x=50*m.cos(m.radians(i))+40*m.cos(m.radians(i+j))
      y=50*m.sin(m.radians(i))+40*m.sin(m.radians(i+j))
      si=i+j
      arr.append(np.array((i,j,x,y))) 
  mo_phong.extend(arr)

# %%
header = ['tt1', 'tt2', 'Px', 'Py',]
#header = [ 'x', 'y']
with open('Robot2bac.csv', 'w', encoding='UTF8', newline='') as data_table:
    writer = csv.writer(data_table)
    writer.writerow(header)
    writer.writerows(mo_phong)

# %%
import pandas as pd
data = pd.read_csv ('Robot2bac.csv')
data.head()
# Out:
#    tt1  tt2         Px        Py
# 0  0.0  0.0  90.000000  0.000000
# 1  0.0  1.0  89.993908  0.698096
# 2  0.0  2.0  89.975633  1.395980
# 3  0.0  3.0  89.945181  2.093438
# 4  0.0  4.0  89.902562  2.790259

# %%
x=data.iloc[:,[2,3]]
y=data.iloc[:,[0,1]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=7)

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.callbacks import EarlyStopping

model=Sequential() 
model.add(Dense(512,activation='relu',input_shape=(2,))) 
model.add(Dropout(0.1))
model.add(Dense(512,activation='relu')) 
model.add(Dropout(0.1))
model.add(Dense(512,activation='relu')) 
model.add(Dropout(0.1))
model.add(Dense(2,activation='linear'))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 512)               1536
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_10 (Dense)            (None, 512)               262656
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_11 (Dense)            (None, 512)               262656
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_12 (Dense)            (None, 2)                 1026
#
# =================================================================
# Total params: 527,874
# Trainable params: 527,874
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse',metrics=['mean_absolute_error'])
history= model.fit(x_train, y_train, batch_size=100, epochs=50, verbose=1, validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', patience=50)])
# Out:
# Epoch 1/50
# 208/208 [==============================] - 5s 18ms/step - loss: 3666.5740 - mean_absolute_error: 43.7343 - val_loss: 1861.6080 - val_mean_absolute_error: 33.0940
# Epoch 2/50
# 208/208 [==============================] - 3s 17ms/step - loss: 980.6844 - mean_absolute_error: 22.7319 - val_loss: 979.4466 - val_mean_absolute_error: 20.1167
# Epoch 3/50
# 208/208 [==============================] - 4s 17ms/step - loss: 561.2085 - mean_absolute_error: 16.9780 - val_loss: 468.0514 - val_mean_absolute_error: 16.0147
# Epoch 4/50
# 208/208 [==============================] - 5s 24ms/step - loss: 423.3285 - mean_absolute_error: 14.8515 - val_loss: 534.1516 - val_mean_absolute_error: 18.6783
# Epoch 5/50
# 208/208 [==============================] - 4s 17ms/step - loss: 356.9881 - mean_absolute_error: 13.6772 - val_loss: 760.0539 - val_mean_absolute_error: 23.1113
# Epoch 6/50
# 208/208 [==============================] - 4s 17ms/step - loss: 313.7432 - mean_absolute_error: 12.9825 - val_loss: 104.6158 - val_mean_absolute_error: 8.0635
# Epoch 7/50
# 208/208 [==============================] - 5s 24ms/step - loss: 287.7837 - mean_absolute_error: 12.4268 - val_loss: 90.9303 - val_mean_absolute_error: 6.8980
# Epoch 8/50
# 208/208 [==============================] - 6s 31ms/step - loss: 266.3987 - mean_absolute_error: 12.1619 - val_loss: 539.8909 - val_mean_absolute_error: 17.2065
# Epoch 9/50
# 208/208 [==============================] - 6s 31ms/step - loss: 254.6794 - mean_absolute_error: 11.8960 - val_loss: 391.6945 - val_mean_absolute_error: 14.8742
# Epoch 10/50
# 208/208 [==============================] - 7s 34ms/step - loss: 236.7508 - mean_absolute_error: 11.4235 - val_loss: 299.0533 - val_mean_absolute_error: 12.1610
# Epoch 11/50
# 208/208 [==============================] - 5s 25ms/step - loss: 227.6105 - mean_absolute_error: 11.1800 - val_loss: 137.1729 - val_mean_absolute_error: 8.4321
# Epoch 12/50
# 208/208 [==============================] - 4s 17ms/step - loss: 217.4722 - mean_absolute_error: 10.9942 - val_loss: 94.8976 - val_mean_absolute_error: 6.7091
# Epoch 13/50
# 208/208 [==============================] - 4s 18ms/step - loss: 204.6588 - mean_absolute_error: 10.7326 - val_loss: 295.1556 - val_mean_absolute_error: 13.9666
# Epoch 14/50
# 208/208 [==============================] - 4s 17ms/step - loss: 194.5256 - mean_absolute_error: 10.4557 - val_loss: 93.0036 - val_mean_absolute_error: 7.3137
# Epoch 15/50
# 208/208 [==============================] - 4s 17ms/step - loss: 182.9077 - mean_absolute_error: 10.1161 - val_loss: 125.1823 - val_mean_absolute_error: 8.2854
# Epoch 16/50
# 208/208 [==============================] - 4s 17ms/step - loss: 170.7351 - mean_absolute_error: 9.7996 - val_loss: 189.7243 - val_mean_absolute_error: 10.3102
# Epoch 17/50
# 208/208 [==============================] - 4s 17ms/step - loss: 160.7729 - mean_absolute_error: 9.4691 - val_loss: 73.4893 - val_mean_absolute_error: 6.1985
# Epoch 18/50
# 208/208 [==============================] - 4s 18ms/step - loss: 146.1792 - mean_absolute_error: 8.9851 - val_loss: 112.7205 - val_mean_absolute_error: 8.1469
# Epoch 19/50
# 208/208 [==============================] - 4s 17ms/step - loss: 136.2223 - mean_absolute_error: 8.6866 - val_loss: 89.2324 - val_mean_absolute_error: 7.7594
# Epoch 20/50
# 208/208 [==============================] - 4s 17ms/step - loss: 130.6085 - mean_absolute_error: 8.4699 - val_loss: 93.6652 - val_mean_absolute_error: 7.1722
# Epoch 21/50
# 208/208 [==============================] - 4s 17ms/step - loss: 122.4478 - mean_absolute_error: 8.1448 - val_loss: 94.6144 - val_mean_absolute_error: 7.3082
# Epoch 22/50
# 208/208 [==============================] - 4s 18ms/step - loss: 115.5704 - mean_absolute_error: 7.9649 - val_loss: 95.5873 - val_mean_absolute_error: 7.1935
# Epoch 23/50
# 208/208 [==============================] - 4s 18ms/step - loss: 109.5498 - mean_absolute_error: 7.7354 - val_loss: 158.6771 - val_mean_absolute_error: 9.1558
# Epoch 24/50
# 208/208 [==============================] - 4s 17ms/step - loss: 106.5656 - mean_absolute_error: 7.5940 - val_loss: 51.9730 - val_mean_absolute_error: 4.9438
# Epoch 25/50
# 208/208 [==============================] - 4s 18ms/step - loss: 103.0322 - mean_absolute_error: 7.4883 - val_loss: 99.8719 - val_mean_absolute_error: 7.7435
# Epoch 26/50
# 208/208 [==============================] - 4s 20ms/step - loss: 98.8574 - mean_absolute_error: 7.3269 - val_loss: 45.5529 - val_mean_absolute_error: 4.5246
# Epoch 27/50
# 208/208 [==============================] - 4s 21ms/step - loss: 95.2859 - mean_absolute_error: 7.2259 - val_loss: 116.8337 - val_mean_absolute_error: 7.9213
# Epoch 28/50
# 208/208 [==============================] - 4s 21ms/step - loss: 90.9249 - mean_absolute_error: 7.0423 - val_loss: 60.8316 - val_mean_absolute_error: 5.9160
# Epoch 29/50
# 208/208 [==============================] - 4s 21ms/step - loss: 92.4553 - mean_absolute_error: 7.0929 - val_loss: 144.6806 - val_mean_absolute_error: 9.8947
# Epoch 30/50
# 208/208 [==============================] - 4s 18ms/step - loss: 85.4544 - mean_absolute_error: 6.8575 - val_loss: 148.0912 - val_mean_absolute_error: 8.9244
# Epoch 31/50
# 208/208 [==============================] - 4s 17ms/step - loss: 85.0825 - mean_absolute_error: 6.7712 - val_loss: 105.4968 - val_mean_absolute_error: 7.8561
# Epoch 32/50
# 208/208 [==============================] - 4s 17ms/step - loss: 80.9751 - mean_absolute_error: 6.6675 - val_loss: 59.6409 - val_mean_absolute_error: 5.2446
# Epoch 33/50
# 208/208 [==============================] - 4s 17ms/step - loss: 79.4203 - mean_absolute_error: 6.6151 - val_loss: 96.4617 - val_mean_absolute_error: 6.7988
# Epoch 34/50
# 208/208 [==============================] - 4s 17ms/step - loss: 79.1611 - mean_absolute_error: 6.5889 - val_loss: 189.9392 - val_mean_absolute_error: 10.9914
# Epoch 35/50
# 208/208 [==============================] - 4s 20ms/step - loss: 77.4244 - mean_absolute_error: 6.5336 - val_loss: 142.6575 - val_mean_absolute_error: 8.9620
# Epoch 36/50
# 208/208 [==============================] - 4s 17ms/step - loss: 74.0800 - mean_absolute_error: 6.3751 - val_loss: 234.6536 - val_mean_absolute_error: 11.8119
# Epoch 37/50
# 208/208 [==============================] - 4s 19ms/step - loss: 75.4726 - mean_absolute_error: 6.4152 - val_loss: 113.5838 - val_mean_absolute_error: 7.1798
# Epoch 38/50
# 208/208 [==============================] - 4s 19ms/step - loss: 72.7136 - mean_absolute_error: 6.3055 - val_loss: 187.8952 - val_mean_absolute_error: 9.0097
# Epoch 39/50
# 208/208 [==============================] - 4s 17ms/step - loss: 70.9707 - mean_absolute_error: 6.2557 - val_loss: 77.3107 - val_mean_absolute_error: 7.2567
# Epoch 40/50
# 208/208 [==============================] - 4s 17ms/step - loss: 70.5192 - mean_absolute_error: 6.2439 - val_loss: 99.4120 - val_mean_absolute_error: 8.1097
# Epoch 41/50
# 208/208 [==============================] - 3s 17ms/step - loss: 69.1767 - mean_absolute_error: 6.1584 - val_loss: 123.2307 - val_mean_absolute_error: 8.9506
# Epoch 42/50
# 208/208 [==============================] - 4s 17ms/step - loss: 68.6065 - mean_absolute_error: 6.1613 - val_loss: 183.8697 - val_mean_absolute_error: 9.7287
# Epoch 43/50
# 208/208 [==============================] - 4s 17ms/step - loss: 66.9149 - mean_absolute_error: 6.0800 - val_loss: 74.1916 - val_mean_absolute_error: 6.9798
# Epoch 44/50
# 208/208 [==============================] - 4s 17ms/step - loss: 66.7336 - mean_absolute_error: 6.0549 - val_loss: 111.2408 - val_mean_absolute_error: 7.8377
# Epoch 45/50
# 208/208 [==============================] - 4s 17ms/step - loss: 66.1876 - mean_absolute_error: 6.0411 - val_loss: 82.0842 - val_mean_absolute_error: 5.9023
# Epoch 46/50
# 208/208 [==============================] - 4s 18ms/step - loss: 64.0986 - mean_absolute_error: 5.9579 - val_loss: 105.2892 - val_mean_absolute_error: 7.7653
# Epoch 47/50
# 208/208 [==============================] - 4s 17ms/step - loss: 64.0487 - mean_absolute_error: 5.9552 - val_loss: 51.2969 - val_mean_absolute_error: 5.3431
# Epoch 48/50
# 208/208 [==============================] - 4s 18ms/step - loss: 63.3825 - mean_absolute_error: 5.9296 - val_loss: 286.8069 - val_mean_absolute_error: 12.1194
# Epoch 49/50
# 208/208 [==============================] - 4s 17ms/step - loss: 62.7560 - mean_absolute_error: 5.9147 - val_loss: 138.1313 - val_mean_absolute_error: 8.3433
# Epoch 50/50
# 208/208 [==============================] - 4s 18ms/step - loss: 62.0195 - mean_absolute_error: 5.8706 - val_loss: 177.2635 - val_mean_absolute_error: 8.9855

# %%
score=model.evaluate(x_test,y_test,verbose=0)
print('Test loss',score[0])
print('Test accuracy',score[1])
# Out:
# Test loss 174.46450805664062
# Test accuracy 8.973556518554688

# %%
predictions=model.predict(x_test)
y_test=np.array(y_test)
print("gia tri du doan:", predictions[12])
print("gia tri thuc:",y_test[12])
# Out:
# gia tri du doan: [ 37.832752 160.09413 ]
# gia tri thuc: [ 39. 156.]
