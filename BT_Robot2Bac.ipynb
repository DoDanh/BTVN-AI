# %%
import math as m
import numpy as np
import csv
mo_phong=[]
for i in range(0,180,1):
  arr=[]  
  for j in range(0,180,1):
      x=50*m.cos(m.radians(i))+40*m.cos(m.radians(i+j))
      y=50*m.sin(m.radians(i))+40*m.sin(m.radians(i+j))
      si=i+j
      arr.append(np.array((i,j,x,y))) 
  mo_phong.extend(arr)

# %%
header = ['tt1', 'tt2', 'Px', 'Py',]
#header = [ 'x', 'y']
with open('Robot2bac.csv', 'w', encoding='UTF8', newline='') as data_table:
    writer = csv.writer(data_table)
    writer.writerow(header)
    writer.writerows(mo_phong)

# %%
import pandas as pd
data = pd.read_csv ('Robot2bac.csv')
data.head()
# Out:
#    tt1  tt2         Px        Py
# 0  0.0  0.0  90.000000  0.000000
# 1  0.0  1.0  89.993908  0.698096
# 2  0.0  2.0  89.975633  1.395980
# 3  0.0  3.0  89.945181  2.093438
# 4  0.0  4.0  89.902562  2.790259

# %%
x=data.iloc[:,[2,3]]
y=data.iloc[:,[0,1]]

# %%
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler
cal_names = list(x.columns)
scaler = StandardScaler()
x_df = scaler.fit_transform(x)
x_df = pd.DataFrame(x_df,columns=cal_names)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_df,y,test_size=0.25,random_state=7)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping

model=Sequential() 
model.add(Dense(20,kernel_initializer='normal', activation='relu',input_shape=(2,)))
model.add(Dense(20,activation='relu')) 
model.add(Dense(20,activation='relu')) 
model.add(Dense(2,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_33 (Dense)            (None, 20)                60
#
#  dense_34 (Dense)            (None, 20)                420
#
#  dense_35 (Dense)            (None, 20)                420
#
#  dense_36 (Dense)            (None, 2)                 42
#
# =================================================================
# Total params: 942
# Trainable params: 942
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train_scale=scale(x_train)
scaler=StandardScaler().fit(x_train)
x_test_scale=scaler.transform(x_test)

# %%
model.compile(loss='mse',metrics=['mean_absolute_error'])
history = model.fit(x_train_scale,y_train,epochs=10,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/10
# 608/608 [==============================] - 5s 6ms/step - loss: 10564.8818 - mean_absolute_error: 88.7370 - val_loss: 10565.4736 - val_mean_absolute_error: 88.8956
# Epoch 2/10
# 608/608 [==============================] - 3s 5ms/step - loss: 10559.6709 - mean_absolute_error: 88.7358 - val_loss: 10564.7246 - val_mean_absolute_error: 88.8946
# Epoch 3/10
# 608/608 [==============================] - 3s 5ms/step - loss: 10559.1172 - mean_absolute_error: 88.7352 - val_loss: 10564.3359 - val_mean_absolute_error: 88.8945
# Epoch 4/10
# 608/608 [==============================] - 3s 5ms/step - loss: 10558.9775 - mean_absolute_error: 88.7352 - val_loss: 10564.4424 - val_mean_absolute_error: 88.8947
# Epoch 5/10
# 608/608 [==============================] - 3s 5ms/step - loss: 10558.9189 - mean_absolute_error: 88.7352 - val_loss: 10564.3125 - val_mean_absolute_error: 88.8947
# Epoch 6/10
# 608/608 [==============================] - 3s 5ms/step - loss: 10558.8936 - mean_absolute_error: 88.7351 - val_loss: 10564.2412 - val_mean_absolute_error: 88.8944
# Epoch 7/10
# 608/608 [==============================] - 1s 2ms/step - loss: 10558.8789 - mean_absolute_error: 88.7352 - val_loss: 10564.1768 - val_mean_absolute_error: 88.8943
# Epoch 8/10
# 608/608 [==============================] - 1s 2ms/step - loss: 10558.8721 - mean_absolute_error: 88.7350 - val_loss: 10564.1836 - val_mean_absolute_error: 88.8944
# Epoch 9/10
# 608/608 [==============================] - 1s 2ms/step - loss: 10558.8467 - mean_absolute_error: 88.7351 - val_loss: 10564.2314 - val_mean_absolute_error: 88.8942
# Epoch 10/10
# 608/608 [==============================] - 1s 2ms/step - loss: 10558.8428 - mean_absolute_error: 88.7351 - val_loss: 10564.1914 - val_mean_absolute_error: 88.8944

# %%
score=model.evaluate(x_test_scale,y_test,verbose=0)
print('Test loss',score[0])
print('Test accuracy',score[1])
# Out:
# Test loss 10685.408203125
# Test accuracy 89.70231628417969
